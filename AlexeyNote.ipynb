# %% [markdown]
# <a href="https://colab.research.google.com/github/Olex1313/DataPlotting/blob/main/AlexeyNote.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os

# %%
data = pd.read_csv('hack.csv', sep = ';')

data
# Out:
#       Unnamed: 0         nplv  ... химшлак последний R химшлак последний SiO2
# 0              0  г6837?3<87?  ...                 2,6                    NaN
# 1              1  г683863<886  ...                 2,3                    NaN
# 2              2  г683863<887  ...                 2,3                    NaN
# 3              3  г683863<888  ...                 2,6                    NaN
# 4              4  г683863<889  ...                 2,5                    NaN
# ...          ...          ...  ...                 ...                    ...
# 7036        7036  г68386398<;  ...                 2,7                   22,8
# 7037        7037  г68386398<<  ...                 2,4                   22,3
# 7038        7038  г68386398<=  ...                 2,2                   25,0
# 7039        7039  г68386398<>  ...                 2,1                   26,0
# 7040        7040  г68386398<?  ...                 2,3                   25,5
#
# [7041 rows x 85 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7041 entries, 0 to 7040
# Data columns (total 85 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      7041 non-null   int64
#  1   nplv                            7041 non-null   object
#  2   DT                              7041 non-null   object
#  3   МАРКА                           7041 non-null   object
#  4   ПРОФИЛЬ                         7041 non-null   object
#  5   t вып-обр                       6444 non-null   object
#  6   t обработка                     6440 non-null   object
#  7   t под током                     6440 non-null   object
#  8   t продувка                      6444 non-null   object
#  9   ПСН гр.                         5249 non-null   object
#  10  чист расход C                   6435 non-null   object
#  11  чист расход Cr                  5883 non-null   object
# ...

# %%
s = pd.Series(['A', 'B', 'C'])
for index, value in s.items():
    s[index] = 0
print(s)
# Out:
# 0    0
# 1    0
# 2    0
# dtype: object
